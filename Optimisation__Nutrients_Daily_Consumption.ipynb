# %%
import pandas as pd
import numpy as np
import csv
from pathlib import Path 
import re
import string

# %%
df= pd.read_csv(r'/Users/lolitalolita/Downloads/nutrients.csv')

# %%
df.Category.unique()
# Out:
# array(['Dairy products', 'Fats, Oils, Shortenings', 'Meat, Poultry',
#        'Fish, Seafood', 'Vegetables A-E', 'Vegetables F-P',
#        'Vegetables R-Z', 'Fruits A-F', 'Fruits G-P', 'Fruits R-Z',
#        'Breads, cereals, fastfood,grains', 'Soups', 'Desserts, sweets',
#        'Jams, Jellies', 'Seeds and Nuts', 'Drinks,Alcohol, Beverages'],
#       dtype=object)

# %%
df=df.replace("t",0)
df=df.replace("t'",0)
df['Fiber']=df['Fiber'].replace("a","", regex=True)

# %%
df=df.replace(",","", regex=True)
df['Calories'][91]=(8+44)/2

# %%
df['Grams']=pd.to_numeric(df['Grams'])
df['Calories']=pd.to_numeric(df['Calories'])
df['Protein']=pd.to_numeric(df['Protein'])
df['Fat']=pd.to_numeric(df['Fat'])
df['Sat.Fat']=pd.to_numeric(df['Sat.Fat'])
df['Fiber']=pd.to_numeric(df['Fiber'])
df['Carbs']=pd.to_numeric(df['Carbs'])

# %%
df=df.dropna()

# %%
df
# Out:
#                      Food Measure  Grams  Calories  Protein  Fat  Sat.Fat  \
# 0              Cows' milk   1 qt.    976     660.0       32   40     36.0
# 1               Milk skim   1 qt.    984     360.0       36    0      0.0
# 2              Buttermilk   1 cup    246     127.0        9    5      4.0
# 3    Evaporated undiluted   1 cup    252     345.0       16   20     18.0
# 4          Fortified milk  6 cups   1419    1373.0       89   42     23.0
# ..                    ...     ...    ...       ...      ...  ...      ...
# 330   Fruit-flavored soda  12 oz.    346     161.0        0    0      0.0
# 331            Ginger ale  12 oz.    346     105.0        0    0      0.0
# 332             Root beer  12 oz.    346     140.0        0    0      0.0
# 333                Coffee   1 cup    230       3.0        0    0      0.0
# 334                   Tea   1 cup    230       4.0        0    0      0.0
#
#      Fiber  Carbs                 Category
# 0      0.0   48.0           Dairy products
# 1      0.0   52.0           Dairy products
# 2      0.0   13.0           Dairy products
# 3      0.0   24.0           Dairy products
# 4      1.4  119.0           Dairy products
# ..     ...    ...                      ...
# 330    0.0   42.0  DrinksAlcohol Beverages
# 331    0.0   28.0  DrinksAlcohol Beverages
# 332    0.0   35.0  DrinksAlcohol Beverages
# 333    0.0    1.0  DrinksAlcohol Beverages
# 334    0.0    1.0  DrinksAlcohol Beverages
#
# [331 rows x 10 columns]

# %%
df.Measure.unique()
# Out:
# array(['1 qt.', '1 cup', '6 cups', '1 1/3 cups', '2/3 cup', '2 cups',
#        '1/2 cup', '1-in. cube', '1 oz.', '2', '1T.', '1/4\xa0lb.', '1 T.',
#        '2 slices', '3 oz.', '2 oz.', '1 pie', '3 1/2 oz.', '3 med.',
#        '4 oz.', '5', '1 small', 'aver.', '6-8 med.', '1 steak', '1 large',
#        '6 spears', '3/4 cup', '1 mad.', '1 ear', '8', '1/4 head', '4',
#        '1', '6 small', '2 T.', '4 cups', '1 pod', '1 med.', '10 pieces',
#        '10', '5 small', '1/3 cup', '1 med', '1/2 large', '1/2 med.', '3',
#        '1/2', '6-oz. can', '8 oz. or', '1 large slice', 'I med.',
#        '1 wedge', '1 slice', '1-lb. loaf', '1 serving', '2 med.',
#        '1 section', '2 pieces', '2-oz. bar', '12 oz.'], dtype=object)

# %%
df.dtypes
# Out:
# Food         object
# Measure      object
# Grams         int64
# Calories    float64
# Protein       int64
# Fat           int64
# Sat.Fat     float64
# Fiber       float64
# Carbs       float64
# Category     object
# dtype: object

# %%
# Import PuLP modeler functions
from pulp import *

# %%
# Create the 'prob' variable to contain the problem data
prob = LpProblem("Minimal_sugar_intake", LpMinimize)

# %%
Name_dict = list(df['Food'])

Calories_dict = dict(zip(Name_dict, df['Calories']))
Protein_dict = dict(zip(Name_dict, df['Protein']))
Sat_Fat_dict = dict(zip(Name_dict, df['Sat.Fat']))
Fat_dict = dict(zip(Name_dict, df['Fat']))
Fiber_dict = dict(zip(Name_dict, df['Fiber']))
Carbs_dict = dict(zip(Name_dict, df['Carbs']))

# %%
# A dictionary called 'recipe_name_vars' is created to contain the referenced Variables
food_name_vars = LpVariable.dicts("R", Name_dict,lowBound=0,cat='Continuous')

# %%
# The constraints are added to 'prob'
# The objective function is added to 'prob' first

prob += (
    lpSum([Sat_Fat_dict[i] * food_name_vars[i] for i in Name_dict]),
    "Total sugar content per dish")

prob += (
    lpSum([Protein_dict[i] * food_name_vars[i] for i in Name_dict]) <= 70.0,
    "Protein_dict_Requirement_max",
)
prob += (
    lpSum([Protein_dict[i] * food_name_vars[i] for i in Name_dict]) >= 40.0,
    "Protein_dict_Requirement_min",
)

prob += (
    lpSum([Calories_dict[i] * food_name_vars[i] for i in Name_dict]) <= 2000.0,
    "Calories_dict_Requirement_max",
)
prob += (
    lpSum([Calories_dict[i] * food_name_vars[i] for i in Name_dict]) >= 1500.0,
    "Calories_dict_Requirement_min",
)

prob += (
    lpSum([Fat_dict[i] * food_name_vars[i] for i in Name_dict]) <= 97.0,
    "Fat_dict_Requirement_max",
)
prob += (
    lpSum([Fat_dict[i] * food_name_vars[i] for i in Name_dict]) >= 70.0,
    "Fat_dict_Requirement_min",
)

prob += (
    lpSum([Fiber_dict[i] * food_name_vars[i] for i in Name_dict]) <= 40.0,
    "Fiber_dict_Requirement_max",
)
prob += (
    lpSum([Fiber_dict[i] * food_name_vars[i] for i in Name_dict]) >= 25.0,
    "Fiber_dict_Requirement_min",
)

prob += (
    lpSum([Carbs_dict[i] * food_name_vars[i] for i in Name_dict]) <= 225.0,
    "Carbs_dict_Requirement_max",
)
prob += (
    lpSum([Carbs_dict[i] * food_name_vars[i] for i in Name_dict]) >= 180.0,
    "Carbs_dict_Requirement_min",
)

# %%
# The problem data is written to an .lp file
prob.writeLP("RecipeModel.lp")
# Out:
# [R_(1_2_cup_ice_cream),
#  R_(cornstarch),
#  R_3_teaspoons_sugar,
#  R_9"_diam._pie,
#  R_Almonds,
#  R_Apple_betty,
#  R_Apple_juice_canned,
#  R_Apple_vinegar,
#  R_Apples_raw,
#  R_Apricots,
#  R_Artichoke,
#  R_Asparagus,
#  R_Avocado,
#  R_Bacon,
#  R_Baked_with_cheese,
#  R_Banana,
#  R_Bean_soups,
#  R_Bean_sprouts,
#  R_Beans,
#  R_Beef,
#  R_Beef_soup,
#  R_Beer,
#  R_Beet_greens,
#  R_Biscuits,
#  R_Blackberries,
#  R_Blueberries,
#  R_Bouillon,
#  R_Bran_flakes,
#  R_Brazil_nuts,
#  R_Bread_cracked_wheat,
#  R_Bread_pudding,
#  R_Broccoli,
#  R_Brown_firm_packed_dark_sugar,
#  R_Brussels_sprouts,
#  R_Butter,
#  R_Buttermilk,
#  R_Cakes,
#  R_Candied,
#  R_Candy,
#  R_Cane_Syrup,
#  R_Cantaloupe,
#  R_Carrots,
#  R_Cashews,
#  R_Cauliflower,
#  R_Celery,
#  R_Chard_steamed,
#  R_Cheddar,
#  R_Cheddar_grated_cup,
#  R_Cheese,
#  R_Cherries,
#  R_Cherry_Pie,
#  R_Chicken_livers_fried,
#  R_Chocolate_creams,
#  R_Chocolate_fudge,
#  R_Chocolate_syrup,
#  R_Clam_chowder,
#  R_Clams,
#  R_Cocoa,
#  R_Cod,
#  R_Coffee,
#  R_Cola_drinks,
#  R_Collards,
#  R_Converted,
#  R_Corn,
#  R_Corn_bread_ground_meal,
#  R_Corn_grits_cooked,
#  R_Corn_meal,
#  R_Corn_oil,
#  R_Corned_beef,
#  R_Corned_beef_hash_Dried,
#  R_Corned_beef_hash_Stew,
#  R_Corned_beef_hash_canned,
#  R_Cornflakes,
#  R_Cows'_milk,
#  R_Crab_meat,
#  R_Crackers,
#  R_Cranberry_sauce_sweetened,
#  R_Cream_cheese,
#  R_Cream_or_half_and_half,
#  R_Cream_soups,
#  R_Cucumbers,
#  R_Cupcake,
#  R_Custard,
#  R_Dandelion_greens,
#  R_Dates,
#  R_Doughnuts,
#  R_Dried_uncooked,
#  R_Duck_domestic,
#  R_Eggplant,
#  R_Eggs_Scrambled_or_fried,
#  R_Eggs_raw,
#  R_Endive,
#  R_European_as_Muscat_Tokay,
#  R_Evaporated_undiluted,
#  R_Farina,
#  R_Figs,
#  R_Fish_sticks_fried,
#  R_Flounder,
#  R_Flour,
#  R_Fortified_milk,
#  R_French_dressing,
#  R_French_fried,
#  R_Fresh,
#  R_Fresh_raw,
#  R_Fresh_raw_figs,
#  R_Fresh_steamed_peas,
#  R_Fried_breast_or_leg_and_thigh_chicken,
#  R_Frozen_,
#  R_Fruit_cake,
#  R_Fruit_cocktail_canned,
#  R_Fruit_flavored_soda,
#  R_Fudge,
#  R_Gelatin_made_with_water,
#  R_Gin,
#  R_Ginger_ale,
#  R_Gingerbread,
#  R_Goats'_milk,
#  R_Grape_juice,
#  R_Grapefruit_fresh_5"_diameter,
#  R_Grapefruit_juice,
#  R_Grapefruit_sections,
#  R_Grapes,
#  R_Ground_lean,
#  R_Haddock,
#  R_Halibut,
#  R_Ham_as_,
#  R_Ham_canned_spiced,
#  R_Ham_pan_broiled,
#  R_Hamburger,
#  R_Hard_candies,
#  R_Herring,
#  R_Honey,
#  R_Hydrogenated_cooking_fat,
#  R_Ice_cream,
#  R_Ice_milk,
#  R_Iceberg,
#  R_Ices,
#  R_Jellies,
#  R_Kale,
#  R_Kohlrabi,
#  R_Lamb_chop_broiled,
#  R_Lambs_quarters_steamed,
#  R_Lard,
#  R_Leg_roasted,
#  R_Lemon_juice,
#  R_Lemon_meringue,
#  R_Lemonade_concentratefrozen,
#  R_Lentils,
#  R_Lettuce,
#  R_Lima,
#  R_Lima_dry_cooked,
#  R_Limeade_concentrate_frozen,
#  R_Lobster,
#  R_Macaroni,
#  R_Margarine,
#  R_Margarine_2_pat_or,
#  R_Marshmallows,
#  R_Mayonnaise,
#  R_Milk_chocolate,
#  R_Milk_skim,
#  R_Mince,
#  R_Molasses,
#  R_Muffins,
#  R_Mushrooms_canned,
#  R_Mustard_greens,
#  R_Navy_baked_with_pork,
#  R_Nectar_or_juice,
#  R_Noodle,
#  R_Noodles,
#  R_Oatmeal,
#  R_Okra,
#  R_Olive_oil,
#  R_OlivesRipe,
#  R_Olives_large,
#  R_Onions,
#  R_Orange_juice,
#  R_Oranges_3"_diameter,
#  R_Oyster_stew,
#  R_Oysters,
#  R_Pancakes_4"_diam.,
#  R_Papaya,
#  R_Parsley,
#  R_Parsnips,
#  R_Peaches,
#  R_Peanut_butter,
#  R_Peanut_butter_natural,
#  R_Peanuts,
#  R_Pears,
#  R_Peas,
#  R_Pecans,
#  R_Peppers_Raw_green_sweet,
#  R_Peppers_canned,
#  R_Peppers_with_beef_and_crumbs,
#  R_Persimmons,
#  R_Pineapple,
#  R_Pineapple_Crushed,
#  R_Pineapple_juice,
#  R_Pizza_14"_diam.,
#  R_Plain_with_no_icing,
#  R_Plums,
#  R_Popcorn_salted,
#  R_Pork_chop_1_thick,
#  R_Pork_roast,
#  R_Pork_sausage,
#  R_Pot_pie,
#  R_Potato_chips,
#  R_Potatoes_Mashed_with_milk_and_butter,
#  R_Potatoes_baked,
#  R_Potatoes_pan_tried,
#  R_Powdered_milk,
#  R_Processed_cheese,
#  R_Prune_juice,
#  R_Prunes,
#  R_Puddings_Sugar,
#  R_Puffed_rice,
#  R_Puffed_wheat_presweetened,
#  R_Pumpkin_Pie,
#  R_Radishes,
#  R_Raisins,
#  R_Raspberries,
#  R_Raw,
#  R_Raw_2"_diameter,
#  R_Raw_2_by_2_1_2,
#  R_Raw_3_by_2V,
#  R_Raw_diced,
#  R_Raw_grated,
#  R_Raw_green,
#  R_Raw_red,
#  R_Red_kidney,
#  R_Rhubarb_sweetened,
#  R_Rice,
#  R_Rice_flakes,
#  R_Rice_polish,
#  R_Roast,
#  R_Roast_beef,
#  R_Roasted_chicken,
#  R_Rolls,
#  R_Root_beer,
#  R_Roquefort_type,
#  R_Rutabagas,
#  R_Rye,
#  R_Safflower_seed_oil,
#  R_Salmon,
#  R_Sardines,
#  R_Sauerkraut,
#  R_Scalloped_with_cheese_potatoes,
#  R_Scallops,
#  R_Sesame_seeds,
#  R_Shad,
#  R_Shoulder_braised,
#  R_Shredded_wheat_biscuit,
#  R_Shrimp,
#  R_Soda_2_1_2_square,
#  R_Soybeans,
#  R_Spaghetti_with_meat_sauce,
#  R_Spanish_rice,
#  R_Spinach,
#  R_Split_cooked_peas,
#  R_Split_pea_soup,
#  R_Sponge_cake,
#  R_Squash,
#  R_Stalk_raw,
#  R_Steak,
#  R_Steak_lean_as_round,
#  R_Steamed_cabbage,
#  R_Steamed_potatoes_before_peeling,
#  R_Stewed_or_canned,
#  R_Strawberries,
#  R_Strips_from_raw,
#  R_Sunflower_seeds,
#  R_Sweet_potatoes,
#  R_Swiss,
#  R_Swordfish,
#  R_Syrup,
#  R_Table_(12.2%_alcohol),
#  R_Tangerines,
#  R_Tapioca_cream_pudding,
#  R_Tea,
#  R_Thousand_Island_sauce,
#  R_Tomato_catsup,
#  R_Tomato_juice,
#  R_Tomato_soup,
#  R_Tomatoes,
#  R_Tuna,
#  R_Turkey,
#  R_Turnip_greens,
#  R_Turnips_steamed,
#  R_Veal,
#  R_Vegetable,
#  R_Waffles,
#  R_Walnuts,
#  R_Watercress_stems_raw,
#  R_Watermelon,
#  R_Wheat_(all_purpose),
#  R_Wheat_(whole),
#  R_Wheat_cooked,
#  R_Wheat_germ,
#  R_Wheat_germ_cereal_toasted,
#  R_Wheat_meal_cereal_unrefined,
#  R_Wheat_pancakes_4"_diam.,
#  R_White,
#  R_White_20_slices_or,
#  R_Whole_wheat,
#  R_Wines,
#  R_Winter_mashed,
#  R_Yolks,
#  R_chicken,
#  R_chicken_soup,
#  R_coconut_sweetened,
#  R_cooked_or_canned,
#  R_figs_Canned_with_syrup_,
#  R_heated_peas,
#  R_of_refined_flour,
#  R_or_whipping,
#  R_preserves,
#  R_roasted_and_salted,
#  R_skim._milk,
#  R_skim_instant,
#  R_skim_non_instant,
#  R_table_blends_sugar,
#  R_uncreamed,
#  R_whole_wheat,
#  R_with_tomatoes_and_cheese]

# %%
# The problem is solved using PuLP's choice of Solver
prob.solve()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/lolitalolita/opt/anaconda3/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/j9/7y5q0v6x4p3f2fdr5f5ffl0m0000gn/T/42c8d49b9f1347f083e27dc5fc15188c-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/j9/7y5q0v6x4p3f2fdr5f5ffl0m0000gn/T/42c8d49b9f1347f083e27dc5fc15188c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 2605 RHS
# At line 2616 BOUNDS
# At line 2617 ENDATA
# Problem MODEL has 10 rows, 323 columns and 2450 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 9 (-1) rows, 316 (-7) columns and 2102 (-348) elements
# Perturbing problem by 0.001% of 138.26748 - largest nonzero change 0.00096145185 ( 0.013220981%) - largest zero change 0.00094865208
# 0  Obj 0 Primal inf 27.277609 (4)
# 5  Obj 0.00068927932
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
# 1

# %%
# Each of the variables is printed with it's resolved optimum value
    
for v in prob.variables():
    if v.varValue>0:
        print(v.name, "=", v.varValue)
# Out:
# R_Duck_domestic = 2.0171053
# R_Gin = 2.4865789
# R_Halibut = 1.3447368
# R_Raw = 13.157895
# R_Soda_2_1_2_square = 2.7631579

# %%
# The optimised objective function value is printed to the screen
print("Minimal sugar intake = ", value(prob.objective))
# Out:
# Minimal sugar intake =  0.0

# %% [markdown]
# Exploring the result.
#
# Example:
# We want to check the measurement of each product to translate the result into a daily menu.
# --> 1 serving of domestic duck is 3 1/2 oz. Following our recipe, the daily consumption of domestic duck would be  approx 7 oz.
# --> 1 serving of gin is 1 oz. Following our recipe, the daily consumption of gin would be  approx 2 1/2 oz. However,daily comsumption of alcohol is not good for anyone. This is one of the limitations of the algorithm, even if it is an optimal solution, it does not mean it is a good one.

# %%
df[df['Food']=='Raw']
# Out:
#     Food Measure  Grams  Calories  Protein  Fat  Sat.Fat  Fiber  Carbs  \
# 216  Raw   1 cup    149      54.0        0    0      0.0    1.9   12.0
#
#        Category
# 216  Fruits R-Z

# %%
df[df['Food']=='Gin']
# Out:
#     Food Measure  Grams  Calories  Protein  Fat  Sat.Fat  Fiber  Carbs  \
# 324  Gin   1 oz.     28      70.0        0    0      0.0    0.0    0.0
#
#                     Category
# 324  DrinksAlcohol Beverages

# %%
df[df['Food']=='Halibut']
# Out:
#        Food    Measure  Grams  Calories  Protein  Fat  Sat.Fat  Fiber  Carbs  \
# 78  Halibut  3 1/2 oz.    100     182.0       26    8      0.0    0.0    0.0
#
#         Category
# 78  Fish Seafood

# %%
df[df['Food']=='Duck domestic']
# Out:
#              Food    Measure  Grams  Calories  Protein  Fat  Sat.Fat  Fiber  \
# 59  Duck domestic  3 1/2 oz.    100     370.0       16   28      0.0    0.0
#
#     Carbs      Category
# 59    0.0  Meat Poultry

# %%
df[df['Food']=='Soda 2 1/2 square']
# Out:
#                   Food Measure  Grams  Calories  Protein  Fat  Sat.Fat  Fiber  \
# 231  Soda 2 1/2 square       2     11      45.0        1    1      0.0    0.0
#
#      Carbs                       Category
# 231    8.0  Breads cereals fastfoodgrains
